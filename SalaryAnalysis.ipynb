# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Write a python program to load data into pandas DataFrame.

# %%
import pandas as pd

#reading the "DataScienceSalaries.csv" into pandas dataframe and assigning variable name data
data=pd.read_csv("DataScienceSalaries.csv")
data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# ## Write a python program to remove unnecessary columns i.e., salary and salary currency.

# %%
#dropping the columns salary and salary_currency
data=data.drop(columns=['salary','salary_currency'])
data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# ## Write a python program to remove the NaN missing values from updated dataframe.

# %%
#dropping the rows which has empty cells
data=data.dropna()
data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# ## Write a python program to check duplicates value in the dataframe.

# %%
#finding the duplicated data in dataframe and printing it
duplicateRows = data[data.duplicated()]
print("Duplicate rows:")
print(duplicateRows)
# Out:
# Duplicate rows:
#       work_year experience_level employment_type           job_title  \
# 115        2023               SE              FT      Data Scientist
# 123        2023               SE              FT  Analytics Engineer
# 153        2023               MI              FT       Data Engineer
# 154        2023               MI              FT       Data Engineer
# 160        2023               SE              FT       Data Engineer
# ...         ...              ...             ...                 ...
# 3439       2022               MI              FT      Data Scientist
# 3440       2022               SE              FT       Data Engineer
# 3441       2022               SE              FT       Data Engineer
# 3586       2021               MI              FT       Data Engineer
# 3709       2021               MI              FT      Data Scientist
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# ...

# %% [markdown]
# ## Write a python program to see the unique values from all the columns in the dataframe

# %%
#finding and printing unique value of column work_year
unique_work_year=data['work_year'].unique()
unique_work_year
# Out:
# array([2023, 2022, 2020, 2021], dtype=int64)

# %%
#finding and printing unique value of column experience_level
unique_experience_level=data['experience_level'].unique()
unique_experience_level
# Out:
# array(['SE', 'MI', 'EN', 'EX'], dtype=object)

# %%
#finding and printing unique value of column employment_type
unique_employment_type=data['employment_type'].unique()
unique_employment_type
# Out:
# array(['FT', 'CT', 'FL', 'PT'], dtype=object)

# %%
#finding and printing unique value of column job_title
unique_job_title=data['job_title'].unique()
unique_job_title
# Out:
# array(['Principal Data Scientist', 'ML Engineer', 'Data Scientist',
#        'Applied Scientist', 'Data Analyst', 'Data Modeler',
#        'Research Engineer', 'Analytics Engineer',
#        'Business Intelligence Engineer', 'Machine Learning Engineer',
#        'Data Strategist', 'Data Engineer', 'Computer Vision Engineer',
#        'Data Quality Analyst', 'Compliance Data Analyst',
#        'Data Architect', 'Applied Machine Learning Engineer',
#        'AI Developer', 'Research Scientist', 'Data Analytics Manager',
#        'Business Data Analyst', 'Applied Data Scientist',
#        'Staff Data Analyst', 'ETL Engineer', 'Data DevOps Engineer',
#        'Head of Data', 'Data Science Manager', 'Data Manager',
#        'Machine Learning Researcher', 'Big Data Engineer',
#        'Data Specialist', 'Lead Data Analyst', 'BI Data Engineer',
#        'Director of Data Science', 'Machine Learning Scientist',
#        'MLOps Engineer', 'AI Scientist', 'Autonomous Vehicle Technician',
# ...

# %%
#finding and printing unique value of column salary_in_usd
unique_salary_in_usd=data['salary_in_usd'].unique()
unique_salary_in_usd
# Out:
# array([ 85847,  30000,  25500, ...,  28369, 412000,  94665], dtype=int64)

# %%
#finding and printing unique value of column employee_residence
unique_employee_residence=data['employee_residence'].unique()
unique_employee_residence
# Out:
# array(['ES', 'US', 'CA', 'DE', 'GB', 'NG', 'IN', 'HK', 'PT', 'NL', 'CH',
#        'CF', 'FR', 'AU', 'FI', 'UA', 'IE', 'IL', 'GH', 'AT', 'CO', 'SG',
#        'SE', 'SI', 'MX', 'UZ', 'BR', 'TH', 'HR', 'PL', 'KW', 'VN', 'CY',
#        'AR', 'AM', 'BA', 'KE', 'GR', 'MK', 'LV', 'RO', 'PK', 'IT', 'MA',
#        'LT', 'BE', 'AS', 'IR', 'HU', 'SK', 'CN', 'CZ', 'CR', 'TR', 'CL',
#        'PR', 'DK', 'BO', 'PH', 'DO', 'EG', 'ID', 'AE', 'MY', 'JP', 'EE',
#        'HN', 'TN', 'RU', 'DZ', 'IQ', 'BG', 'JE', 'RS', 'NZ', 'MD', 'LU',
#        'MT'], dtype=object)

# %%
#finding and printing unique value of column remote_ratio
unique_remote_ratio=data['remote_ratio'].unique()
unique_remote_ratio
# Out:
# array([100,   0,  50], dtype=int64)

# %%
#finding and printing unique value of column company_location
unique_company_location=data['company_location'].unique()
unique_company_location
# Out:
# array(['ES', 'US', 'CA', 'DE', 'GB', 'NG', 'IN', 'HK', 'NL', 'CH', 'CF',
#        'FR', 'FI', 'UA', 'IE', 'IL', 'GH', 'CO', 'SG', 'AU', 'SE', 'SI',
#        'MX', 'BR', 'PT', 'RU', 'TH', 'HR', 'VN', 'EE', 'AM', 'BA', 'KE',
#        'GR', 'MK', 'LV', 'RO', 'PK', 'IT', 'MA', 'PL', 'AL', 'AR', 'LT',
#        'AS', 'CR', 'IR', 'BS', 'HU', 'AT', 'SK', 'CZ', 'TR', 'PR', 'DK',
#        'BO', 'PH', 'BE', 'ID', 'EG', 'AE', 'LU', 'MY', 'HN', 'JP', 'DZ',
#        'IQ', 'CN', 'NZ', 'CL', 'MD', 'MT'], dtype=object)

# %%
#finding and printing unique value of column company_size
unique_company_size=data['company_size'].unique()
unique_company_size
# Out:
# array(['L', 'S', 'M'], dtype=object)

# %% [markdown]
# ## 	Rename the experience level columns as below.
# ###  SE – Senior Level/Expert,
# ### MI – Medium Level/Intermediate,
# ### EN – Entry Level,
# ### EX – Executive Level

# %%
#storing the values to replace in dictionary
replace_data = {'SE': 'Senior Level/Expert','MI' : 'Medium Level/Intermediate','EN' : 'Entry Level',
                'EX' : 'Executive Level'}

#replacing the data in experience_level column
data['experience_level'] = data['experience_level'].replace(replace_data)
data
# Out:
#       work_year           experience_level employment_type  \
# 0          2023        Senior Level/Expert              FT
# 1          2023  Medium Level/Intermediate              CT
# 2          2023  Medium Level/Intermediate              CT
# 3          2023        Senior Level/Expert              FT
# 4          2023        Senior Level/Expert              FT
# ...         ...                        ...             ...
# 3750       2020        Senior Level/Expert              FT
# 3751       2021  Medium Level/Intermediate              FT
# 3752       2020                Entry Level              FT
# 3753       2020                Entry Level              CT
# 3754       2021        Senior Level/Expert              FT
#
#                      job_title  salary_in_usd employee_residence  \
# 0     Principal Data Scientist          85847                 ES
# 1                  ML Engineer          30000                 US
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ## 	Write a Python program to show summary statistics of sum, mean, standard deviation, skewness, and kurtosis of any chosen variable

# %%
from scipy.stats import skew, kurtosis

#finding sum, mean, standard deviation, skewness and kurtosis
Answer = {
    'Sum': data['salary_in_usd'].sum(),
    'Mean': data['salary_in_usd'].mean(),
    'Standard Deviation': data['salary_in_usd'].std(),
    'Skewness': skew(data['salary_in_usd']),
    'Kurtosis': kurtosis(data['salary_in_usd'])
}
print(Answer)
# Out:
# {'Sum': 516576814, 'Mean': 137570.38988015978, 'Standard Deviation': 63055.625278224084, 'Skewness': 0.5361868674235593, 'Kurtosis': 0.8312989014514311}

# %% [markdown]
# ## Write a Python program to calculate and show correlation of all variables.

# %%
#selecting only number datatype and finding it's correlation
num_data = data.select_dtypes(include='number')
correlation_matrix = num_data.corr()

print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                work_year  salary_in_usd  remote_ratio
# work_year        1.00000       0.228290     -0.236430
# salary_in_usd    0.22829       1.000000     -0.064171
# remote_ratio    -0.23643      -0.064171      1.000000

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Write a python program to find out top 15 jobs. Make a bar graph of sales as well.

# %%
#finding the top 15 job_titles on basis of number of jobs available
top_fifteen_jobs = data['job_title'].value_counts().head(15)
top_fifteen_jobs
# Out:
# job_title
# Data Engineer                 1040
# Data Scientist                 840
# Data Analyst                   612
# Machine Learning Engineer      289
# Analytics Engineer             103
# Data Architect                 101
# Research Scientist              82
# Data Science Manager            58
# Applied Scientist               58
# Research Engineer               37
# ML Engineer                     34
# Data Manager                    29
# Machine Learning Scientist      26
# Data Science Consultant         24
# Data Analytics Manager          22
# Name: count, dtype: int64

# %%
#showing number of jobs and job titles in bar graph
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
top_fifteen_jobs.plot(kind='bar', color='lightblue')
plt.title('Top 15 Jobs')
plt.xlabel('Job Title')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ##	Which job has the highest salaries? Illustrate with bar graph.

# %%
#showing the job title with highest salaries in bar graph
mean_salary_by_job = data.groupby('job_title')['salary_in_usd'].mean()

#storing data of top 40 highest mean salaries of job titles
highest_40_mean_salary=mean_salary_by_job.sort_values(ascending = False).head(40)

#getting highest salary and it's title
highest_mean_salary_job = highest_40_mean_salary.idxmax()
highest_mean_salary = mean_salary_by_job.max()

#forming bar graph
plt.figure(figsize=(15, 8))
highest_40_mean_salary.plot(kind='bar', color='lightblue')
plt.title('Top 40 Job Title by Average Salary')
plt.xlabel('Job Title')
plt.ylabel('Average Salary (USD)')
plt.xticks(rotation=90, ha='right')
plt.axhline(y=highest_mean_salary, color='r', linestyle='--', label=f'Highest Mean Salary: {highest_mean_salary:.2f} USD ({highest_mean_salary_job})')
plt.legend()

plt.tight_layout()
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## 	Write a python program to find out salaries based on experience level. Illustrate it through bar graph.

# %%
#finding average salary by experience level
mean_salary_by_experience = data.groupby('experience_level')['salary_in_usd'].mean()

plt.figure(figsize=(6, 8))
mean_salary_by_experience.plot(kind='bar', color='lightblue')
plt.title('Average Salary by Experience Level')
plt.xlabel('Experience Level')
plt.ylabel('Average Salary (USD)')
plt.xticks(rotation=90, ha='right')
plt.legend()
plt.tight_layout()
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## Write a Python program to show histogram and box plot of any chosen different variables. Use proper labels in the graph.

# %%
import numpy as np

#histrogram showing number of jobs and salary 
salary=data['salary_in_usd']
b=int((data['salary_in_usd'].max()-data['salary_in_usd'].min())/len(data))

#creating histrogram
plt.figure(figsize=(18, 7))
plt.hist(salary, bins=b, color='skyblue',edgecolor='white')
plt.grid(axis='y')

#setting x label 
xticks_locations = np.linspace(salary.min(), salary.max(), num=b)
plt.xticks(xticks_locations,rotation=90,fontsize=8)

plt.xlabel('Salary in USD')
plt.ylabel('Number of jobs in Data Science')
plt.title('Salary in Data Science')

plt.show()

# %%
#box plot using company size
size=data['company_size'].value_counts()
size.plot(kind='box',title='Box chart by Company Size')
plt.show()
